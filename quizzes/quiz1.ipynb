# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import pandas as pd

df = pd.read_csv('./quizzes/distance1.csv')
x1 = df["t1"]
x2 = df["t2"]
x = np.array([x1, x2]).T
y = np.array(df["y"]).reshape(-1,1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.33)
model = LinearRegression()
model.fit(x_train, y_train)

print(model.coef_, model.intercept_)

y_pred = model.predict(x_test)
# print(np.hstack([y_pred, y_test]))

# Don't remember the specific function for R2, so trying my own implementation
mean = np.mean(y_test)
print(mean)
V = np.sum((mean - y_test)**2)/len(y_test)
MSE = np.sum((y_test - y_pred)**2)/len(y_test)
print(MSE)
R2 = 1 - MSE/V
print(f"R2 value is: {R2}")
# Out:
# [[-31.62592448  22.3894563 ]] [184.62522427]
# 0.0019087859090909027
# 0.12135564306407184
# R2 value is: 0.6600629320307253
